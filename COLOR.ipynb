# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagalo04/Color-Space/blob/master/COLOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path='/content/drive/My Drive/PDI/COLOR/'
os.chdir(path)
# !pwd
# graficar imagenes estadisticas en el notebook

# %matplotlib inline
# Out:
# /content/drive/My Drive/PDI/COLOR

# %%
#Display 4 images

def display4(a,b,c,d,title1="Original",title2="Edited 1",title3="Edited 2",title4="Edited 3"):
  plt.figure(figsize=(14,14))
  plt.subplot(141), plt.imshow(a), plt.title(title1)
  plt.xticks([]), plt.yticks([])
  plt.subplot(142), plt.imshow(b,cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.subplot(143), plt.imshow(c,cmap='gray'), plt.title(title3)
  plt.xticks([]), plt.yticks([])
  plt.subplot(144), plt.imshow(d,cmap='gray'), plt.title(title4)
  plt.xticks([]), plt.yticks([])
  plt.show()

# %% [markdown]
# # **BGR Color Space**

# %%
# leer una imagen
# principle of least astonishment (surprise)
img_BGR=cv2.imread('rub07.jpg',cv2.IMREAD_COLOR)
#b,g,r = cv2.split(img_BGR)

b = img_BGR[:,:,0]
g = img_BGR[:,:,1]
r = img_BGR[:,:,2]

display4(img_BGR,b,g,r,"BGR","b","g","r")

# %%
count=2
plt.figure(figsize=(12,4))
plt.subplot(1,4,1), plt.imshow(img_BGR/255.0), plt.title("original BGR")
plt.axis("off")
for i, lab in enumerate(["B","G","R"]):
  crgb = np.zeros(img_BGR.shape)
  crgb[:,:,i] = img_BGR[:,:,i]
  plt.subplot(1,4,count), plt.imshow(crgb/255.0), plt.title(lab)
  plt.axis("off")
  count +=1

plt.show

# %% [markdown]
# # **RGB Color-Space**

# %%
# pasar a rgb

img_RGB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)
r,g,b = cv2.split(img_RGB)

display4(img_RGB,r,g,b,"BGR","r","g","b")

# %%
count=2
plt.figure(figsize=(12,4))
plt.subplot(1,4,1), plt.imshow(img_RGB/255.0), plt.title("original RGB")
plt.axis("off")
for i, lab in enumerate(["R","G","B"]):
  crgb = np.zeros(img_BGR.shape)
  crgb[:,:,i] = img_RGB[:,:,i]
  plt.subplot(1,4,count), plt.imshow(crgb/255.0), plt.title(lab)
  plt.axis("off")
  count +=1

plt.show

# %% [markdown]
# # **LAB Color-Space**

# %%
# pasar a LAB

img_LAB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2LAB)
L,A,B = cv2.split(img_LAB)

display4(img_LAB,L,A,B,"LAB","L","A","B")

# %% [markdown]
# # **YCrCb Color-Space**

# %%
img_YCrCb=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2YCrCb)
Y,Cr,Cb = cv2.split(img_YCrCb)

display4(img_YCrCb,Y,Cr,Cb,"YCrCb","Y","Cr","Cb")

# %% [markdown]
# # **HSV Color-Space**

# %%
img_HSV=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2HSV)
H,S,V = cv2.split(img_HSV)

display4(img_HSV,H,S,V,"HSV","H","S","V")
